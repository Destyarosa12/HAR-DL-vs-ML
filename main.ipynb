# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
train_data = pd.read_csv('./dataset/train.csv')
test_data = pd.read_csv('./dataset/test.csv')
print(f'Shape of train data: {train_data.shape}\nShape of test data: {test_data.shape}')
# Out:
# Shape of train data: (7352, 563)
# Shape of test data: (2947, 563)

# %%
train_data.head(5)
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
test_data.head(5) #semua feature atau kolom ditampilkan tetapi tampilannya akan terpotong dengan titik
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
# ...

# %%
pd.set_option("display.max_columns", None)

# %%
train_data.head(5) #full feature atau jumlah kolom di tampilkan
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
train_data.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity'],
#       dtype='str', length=563)

# %%
train_data.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        7352.000000        7352.000000        7352.000000
# mean            0.274488          -0.017695          -0.109141
# std             0.070261           0.040811           0.056635
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262975          -0.024863          -0.120993
# 50%             0.277193          -0.017219          -0.108676
# 75%             0.288461          -0.010783          -0.097794
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       7352.000000       7352.000000       7352.000000       7352.000000
# mean          -0.605438         -0.510938         -0.604754         -0.630512
# std            0.448734          0.502645          0.418687          0.424073
# min           -1.000000         -0.999873         -1.000000         -1.000000
# ...

# %%
train_data['Activity'].unique()
# Out:
# <StringArray>
# [          'STANDING',            'SITTING',             'LAYING',
#             'WALKING', 'WALKING_DOWNSTAIRS',   'WALKING_UPSTAIRS']
# Length: 6, dtype: str

# %%
train_data['Activity'].value_counts().sort_values().plot(kind = 'bar', color='skyblue')
# Out:
# <Axes: xlabel='Activity'>

# %%
x_train, y_train = train_data.iloc[:, :-2], train_data.iloc[:, -1:]
x_test, y_test = test_data.iloc[:, :-2], test_data.iloc[:, -1:]
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((7352, 561), (7352, 1), (2947, 561), (2947, 1))

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.fit_transform(y_test)
# Out:
# c:\Users\Destya Rosa\miniconda3\envs\env1\Lib\site-packages\sklearn\preprocessing\_label.py:120: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Destya Rosa\miniconda3\envs\env1\Lib\site-packages\sklearn\preprocessing\_label.py:120: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((7352, 561), (7352,), (2947, 561), (2947,))

# %%
from sklearn.preprocessing import MinMaxScaler
scaling_data = MinMaxScaler()
x_train = scaling_data.fit_transform(x_train)
x_test = scaling_data.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(units=64, kernel_initializer='normal', activation='relu', input_dim=x_train.shape[1]))
model.add(Dropout(0.2))
model.add(Dense(units=6, kernel_initializer='normal', activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=64, epochs=10, validation_data=(x_test, y_test))
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\Destya Rosa\miniconda3\envs\env1\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5868 - loss: 1.0270 - val_accuracy: 0.7486 - val_loss: 0.6892
# Epoch 2/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8135 - loss: 0.5238 - val_accuracy: 0.8554 - val_loss: 0.4293
# Epoch 3/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8656 - loss: 0.3657 - val_accuracy: 0.9067 - val_loss: 0.3117
# Epoch 4/10
# ...

# %%
from tensorflow import keras
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters
import warnings 
warnings.filterwarnings('ignore')

def build_model(hp):
    model = keras.Sequential()
    for i in range(hp.Int('num_layers', 2, 25)):
        model.add(layers.Dense(units = hp.Int('units' + str(i), min_value=32, max_value=512, step=32), kernel_initializer=hp.Choice('initializer', ['uniform', 'normal']), activation=hp.Choice('activation', ['relu', 'sigmoid', 'tanh']))) 
    model.add(layers.Dense(6, kernel_initializer=hp.Choice('initializer', ['uniform', 'normal']), activation='softmax')) 
    model.add(Dropout(0.2)) 
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model
    
tuner = RandomSearch(build_model, 
                     objective='val_accuracy', 
                     max_trials=5, executions_per_trial=3, 
                     directory='project', 
                     project_name='HAR')

tuner.search_space_summary()
# Out:
# C:\Users\Destya Rosa\AppData\Local\Temp\ipykernel_20000\1288417960.py:3: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch
# Reloading Tuner from project\HAR\tuner0.json
# Search space summary
# Default search space size: 18
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 25, 'step': 1, 'sampling': 'linear'}
# units0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# initializer (Choice)
# {'default': 'uniform', 'conditions': [], 'values': ['uniform', 'normal'], 'ordered': False}
# activation (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'sigmoid', 'tanh'], 'ordered': False}
# units1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units2 (Int)
# ...

# %%
tuner.search(x_train, y_train, epochs=10,
             validation_data=(x_test, y_test))

# %%
best_model = tuner.get_best_models(num_models=1)[0]
best_model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\Destya Rosa\miniconda3\envs\env1\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 320)            │       179,840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 480)            │       154,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 6)              │         2,886 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

history = best_model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test), callbacks=[early_stop])
# Out:
# Epoch 1/100
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.7716 - loss: 0.7549 - val_accuracy: 0.9396 - val_loss: 0.5862
# Epoch 2/100
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7734 - loss: 0.6879 - val_accuracy: 0.8551 - val_loss: 2.2876
# Epoch 3/100
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7663 - loss: 0.7785 - val_accuracy: 0.9165 - val_loss: 0.9211
# Epoch 4/100
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.7850 - loss: 0.6838 - val_accuracy: 0.9040 - val_loss: 1.1301

# %%
accuracy = history.history['accuracy']
loss = history.history['loss']
validation_loss = history.history['val_loss']
validation_accuracy = history.history['val_accuracy']

plt.figure(figsize=(15,5))
plt.subplot(2,2,1)
plt.plot(range(len(accuracy)), accuracy, label='Training Accuracy')
plt.plot(range(len(validation_accuracy)), validation_accuracy, label='Validation Accuracy')
plt.legend(loc='upper left')
plt.title('Accuracy : Training Vs Validation')

plt.subplot(2,2,2)
plt.plot(range(len(loss)), loss, label='Training Loss')
plt.plot(range(len(validation_loss)), validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Loss : Training Vs Validation')
plt.show()

# %%
best_val_acc = max(validation_accuracy)
best_epoch = validation_accuracy.index(best_val_acc)

print("Best val_accuracy:", best_val_acc)
print("Best epoch:", best_epoch)

best_val_loss = min(validation_loss)
print("Best val_loss:", best_val_loss)
# Out:
# Best val_accuracy: 0.9395995736122131
# Best epoch: 0
# Best val_loss: 0.5861900448799133

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

y_pred_dl = best_model.predict(x_test)
y_pred_dl = np.argmax(y_pred_dl, axis=1)

cm_dl = confusion_matrix(y_test, y_pred_dl)

sns.heatmap(cm_dl, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix - Deep Learning Model')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
classification_report_dl = classification_report(y_test, y_pred_dl, output_dict=True)
df_dl = pd.DataFrame(classification_report_dl).transpose()
df_dl["Model"] = "Neural Network"
df_dl = df_dl.loc[["macro avg", "weighted avg"]]
print(df_dl)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 classification_report_dl = classification_report(y_test, y_pred_dl, output_dict=True)
#       2 df_dl = pd.DataFrame(classification_report_dl).transpose()
#       3 df_dl["Model"] = "Neural Network"
#
# NameError: name 'classification_report' is not defined

# %%
from sklearn import linear_model
from sklearn.metrics import accuracy_score, classification_report
import pandas as pd

reg = linear_model.LogisticRegression(max_iter=10000, random_state=0)
reg.fit(x_train, y_train)

y_pred_lr = reg.predict(x_test)

accuracy_lr = accuracy_score(y_test, y_pred_lr)
print(f"Accuracy: {accuracy_lr * 100:.2f}%")

classification_report_lr = classification_report(y_test, y_pred_lr, output_dict=True)
df_lr = pd.DataFrame(classification_report_lr).transpose()
df_lr["Model"] = "Logistic Regression"
df_lr = df_lr.loc[["macro avg", "weighted avg"]]
print(df_lr)
# Out:
# Accuracy: 95.66%
#               precision    recall  f1-score  support                Model
# macro avg      0.959199  0.955554  0.956546   2947.0  Logistic Regression
# weighted avg   0.958212  0.956566  0.956541   2947.0  Logistic Regression

# %%
cm_lr = confusion_matrix(y_test, y_pred_lr)

sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix - Logistic Regression Model')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

rf_classifier = RandomForestClassifier(n_estimators=100, random_state=0)
rf_classifier.fit(x_train, y_train)

y_pred_rf = rf_classifier.predict(x_test)
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f"Random Forest Accuracy: {accuracy_rf * 100:.2f}%")
classification_report_rf = classification_report(y_test, y_pred_rf, output_dict=True)
df_rf = pd.DataFrame(classification_report_rf).transpose()
df_rf["Model"] = "Random Forest"
df_rf = df_rf.loc[["macro avg", "weighted avg"]]
print(df_rf)
# Out:
# Random Forest Accuracy: 92.57%
#               precision    recall  f1-score  support          Model
# macro avg      0.926892  0.922421  0.923597   2947.0  Random Forest
# weighted avg   0.926913  0.925687  0.925340   2947.0  Random Forest

# %%
cm_rf = confusion_matrix(y_test, y_pred_rf)

sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix - Random Forest Model')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
from sklearn.svm import SVC
svm = SVC(kernel='linear')
svm.fit(x_train, y_train)

y_pred_svm = svm.predict(x_test)
accuracy_svm = accuracy_score(y_test, y_pred_svm)
print(f"SVM Accuracy: {accuracy_svm * 100:.2f}%")
classification_report_svm = classification_report(y_test, y_pred_svm, output_dict=True)
df_svm = pd.DataFrame(classification_report_svm).transpose()
df_svm["Model"] = "SVM"
df_svm = df_svm.loc[["macro avg", "weighted avg"]]
print(df_svm)
# Out:
# SVM Accuracy: 96.13%
#               precision    recall  f1-score  support Model
# macro avg      0.963275  0.960644  0.961354   2947.0   SVM
# weighted avg   0.962332  0.961317  0.961205   2947.0   SVM

# %%
cm_svm = confusion_matrix(y_test, y_pred_svm)

sns.heatmap(cm_svm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix - SVM Model')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
import pandas as pd

results_acc = pd.DataFrame({
    "Model": ["Logistic Regression",
              "Random Forest", 
              "SVM",
              "Neural Network"],
    "Accuracy": [
                  accuracy_lr * 100,
                  accuracy_rf * 100,
                  accuracy_svm * 100,
                    best_val_acc * 100
              ],
    "Type": ["ML", "ML", "ML", "DL"]
})

print(results_acc.sort_values(by="Accuracy", ascending=False))
# Out:
#                  Model   Accuracy Type
# 2                  SVM  96.131659   ML
# 0  Logistic Regression  95.656600   ML
# 3       Neural Network  93.993890   DL
# 1        Random Forest  92.568714   ML

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(results_acc["Model"], results_acc["Accuracy"], color=['skyblue', 'salmon', 'lightgreen', 'orange'])
plt.title('Model Accuracy Comparison')
plt.xlabel('Model')
plt.ylabel('Accuracy (%)')
plt.ylim(0, 100)
plt.show()

# %%
df_all = pd.concat([df_lr, df_rf, df_svm, df_dl])
df_all = df_all.reset_index().rename(columns={"index": "Metric"})
df_pivot = df_all.pivot(index="Model", columns="Metric", values="f1-score")

df_pivot = df_pivot.round(3)

df_pivot = df_pivot.rename(columns={
    "macro avg": "Macro F1",
    "weighted avg": "Weighted F1"
})

df_pivot = df_pivot.sort_values(by="Weighted F1", ascending=False)

df_pivot.columns.name = None
df_pivot.index.name = None

print(df_pivot)
# Out:
#                      Macro F1  Weighted F1
# SVM                     0.961        0.961
# Logistic Regression     0.957        0.957
# Neural Network          0.938        0.939
# Random Forest           0.924        0.925

# %%
import matplotlib.pyplot as plt
import numpy as np

models = ['SVM', 'Deep Learning']
accuracy = [0.961, 0.939]
macro_f1 = [0.961, 0.938]
weighted_f1 = [0.961, 0.939]

y = np.arange(len(models))
height = 0.25

plt.figure(figsize=(8,5))

# Horizontal bars
plt.barh(y - height, accuracy, height, label='Accuracy')
plt.barh(y, macro_f1, height, label='Macro F1')
plt.barh(y + height, weighted_f1, height, label='Weighted F1')

# Label
plt.yticks(y, models)
plt.xlabel('Score')
plt.title('SVM vs Deep Learning Performance')

plt.legend()

# Value labels
for i in range(len(models)):
    plt.text(accuracy[i], y[i] - height, f"{accuracy[i]*100:.1f}%", va='center')
    plt.text(macro_f1[i], y[i], f"{macro_f1[i]*100:.1f}%", va='center')
    plt.text(weighted_f1[i], y[i] + height, f"{weighted_f1[i]*100:.1f}%", va='center')

plt.tight_layout()
plt.show()
